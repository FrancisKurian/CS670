# %% [markdown]
# <a href="https://colab.research.google.com/github/FrancisKurian/CS670/blob/main/CS670_hw1_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#declare the variables and assign values
a=1.12
b=2.34
c=0.72
d=0.81
f=19.83

print(a,b,c,d,f)
# Out:
# 1.12 2.34 0.72 0.81 19.83

# %%
# problem 1
x=1+(a/b)+(c/f**2)
print("x =",round(x,4))
# Out:
# x = 1.4805

# %%
#problem 2
s= (b-a)/(d-c)
print ("s=", round(s,4))
# Out:
# s= 13.5556

# %%
#problem 3
r= 1/(1/a+1/b+1/c+1/d)
print("r=",round(r,4))
# Out:
# r= 0.2536

# %%
#problem 4
y=a*b*(1/c)*(f**2/2)
print("y=",round(y,4))
# Out:
# y= 715.6766

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.7.0'

# %%
import keras
keras.__version__
# Out:
# '2.7.0'
